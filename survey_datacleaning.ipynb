# %% [markdown]
# <a href="https://colab.research.google.com/github/SwathiJakka/ASCEND_Capstone/blob/main/survey_datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://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@github.com/SwathiJakka/ASCEND_Capstone.git
# Out:
# fatal: destination path 'ASCEND_Capstone' already exists and is not an empty directory.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_survey=pd.read_csv("/content/ASCEND_Capstone/datasets/data_survey.csv")

# %%
df_survey.columns
# Out:
# Index(['Username', 'CourseName', 'ChapterName', 'LessonName', 'Question',
#        'UserAnswer', 'CompletionDate', 'DepartmentName', 'Cohort Name',
#        'Program Version', 'ActiveStatus', 'Gender', 'Age', 'Status in Canada',
#        'Genre', 'Marital Status', 'Country of Birth',
#        'Country you have_will immigrate from',
#        'Year landed in Canada _enter 0 if not yet landed_',
#        'Highest level of education', 'Country', 'Province', 'City',
#        'What is your current employment status',
#        'What industry or sector are you working in',
#        'Is this your preferred industry or sector',
#        'What is your current annual employment salary', 'FirstName',
#        'LastName', 'Phone number', ' Âge', 'Statut au Canada',
#        'Situation maritale', 'Pays de naissance',
#        'Pays d_où vous avez immigré_immigrerez',
#        'Année d_arrivée au Canada _saisir 0 si non applicable_',
#        'Plus haut niveau de formation',
#        'Quelle est votre situation professionnelle actuelle',
#        'Dans quel secteur dactivite ou industrie travaillez_vous',
#        'Est_ce votre secteur ou industrie de prédilection',
#        'Quel est votre salaire annuel actuel', 'Quarterly'],
#       dtype='object')

# %%
df_survey.dtypes
# Out:
# Username                                                     object
# CourseName                                                   object
# ChapterName                                                  object
# LessonName                                                   object
# Question                                                     object
# UserAnswer                                                   object
# CompletionDate                                               object
# DepartmentName                                               object
# Cohort Name                                                  object
# Program Version                                              object
# ActiveStatus                                                 object
# Gender                                                       object
# Age                                                          object
# Status in Canada                                             object
# Genre                                                        object
# Marital Status                                               object
# Country of Birth                                             object
# Country you have_will immigrate from                         object
# Year landed in Canada _enter 0 if not yet landed_           float64
# Highest level of education                                   object
# Country                                                      object
# Province                                                     object
# City                                                         object
# What is your current employment status                       object
# What industry or sector are you working in                   object
# Is this your preferred industry or sector                    object
# What is your current annual employment salary                object
# FirstName                                                    object
# LastName                                                     object
# Phone number                                                 object
#  Âge                                                         object
# Statut au Canada                                             object
# Situation maritale                                           object
# Pays de naissance                                            object
# Pays d_où vous avez immigré_immigrerez                       object
# Année d_arrivée au Canada _saisir 0 si non applicable_       object
# Plus haut niveau de formation                                object
# Quelle est votre situation professionnelle actuelle          object
# Dans quel secteur dactivite ou industrie travaillez_vous     object
# Est_ce votre secteur ou industrie de prédilection            object
# Quel est votre salaire annuel actuel                         object
# Quarterly                                                    object
# dtype: object

# %%
df_survey.head()
# Out:
#             Username                          CourseName  \
# 0  10049na@gmail.com  00. Pre-program consent and survey
# 1  10049na@gmail.com  00. Pre-program consent and survey
# 2  10049na@gmail.com  00. Pre-program consent and survey
# 3  10049na@gmail.com  00. Pre-program consent and survey
# 4  10049na@gmail.com  00. Pre-program consent and survey
#
#                  ChapterName                                       LessonName  \
# 0  ASCEND pre-program survey  Pre-program survey: Soft skills self-assessment
# 1  ASCEND pre-program survey  Pre-program survey: Soft skills self-assessment
# 2  ASCEND pre-program survey  Pre-program survey: Soft skills self-assessment
# 3  ASCEND pre-program survey  Pre-program survey: Soft skills self-assessment
# 4  ASCEND pre-program survey  Pre-program survey: Soft skills self-assessment
#
#                                             Question UserAnswer  \
# 0  I am able to identify new professional network...          4
# 1  I am able to negotiate a job salary\n(5 = Stro...          3
# 2  I am comfortable searching for potential jobs ...          4
# 3  I am confident in my ability to use effective ...          3
# 4  I am confident in my interview skills\n(5 = St...          3
#
#      CompletionDate                                     DepartmentName  \
# 0  2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 1  2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 2  2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 3  2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 4  2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
#
#              Cohort Name Program Version  ... Situation maritale  \
# 0  VIRCS Feb - Apr, 2024          Online  ...                NaN
# 1  VIRCS Feb - Apr, 2024          Online  ...                NaN
# 2  VIRCS Feb - Apr, 2024          Online  ...                NaN
# 3  VIRCS Feb - Apr, 2024          Online  ...                NaN
# 4  VIRCS Feb - Apr, 2024          Online  ...                NaN
#
#   Pays de naissance Pays d_où vous avez immigré_immigrerez  \
# 0               NaN                                    NaN
# 1               NaN                                    NaN
# 2               NaN                                    NaN
# 3               NaN                                    NaN
# 4               NaN                                    NaN
#
#   Année d_arrivée au Canada _saisir 0 si non applicable_  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Plus haut niveau de formation  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   Quelle est votre situation professionnelle actuelle  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Dans quel secteur dactivite ou industrie travaillez_vous  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Est_ce votre secteur ou industrie de prédilection  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Quel est votre salaire annuel actuel            Quarterly
# 0                                   NaN  Jan 2024 - Mar 2024
# 1                                   NaN  Jan 2024 - Mar 2024
# 2                                   NaN  Jan 2024 - Mar 2024
# 3                                   NaN  Jan 2024 - Mar 2024
# 4                                   NaN  Jan 2024 - Mar 2024
#
# [5 rows x 42 columns]

# %%
df_survey.shape
# Out:
# (29375, 42)

# %% [markdown]
# **Handling Duplicates**

# %%
duplicates = df_survey[df_survey.duplicated()]
print(duplicates)
# Out:
#                    Username  \
# 4444  pdpatel2330@gmail.com
#
#                                              CourseName  \
# 4444  Module 6: Onboarding and organizational cultur...
#
#                 ChapterName  \
# 4444  Workshop 5 Evaluation
#
#                                              LessonName  \
# 4444  Evaluation for Workshop 5: Professional commun...
#
#                                                Question UserAnswer  \
# 4444  What was your favourite part of Workshop 5: Pr...        NaN
#
#         CompletionDate                          DepartmentName  \
# 4444  2024-02-15 18:56  Regina Immigrant Women's Centre (RIWC)
#
#                Cohort Name Program Version  ... Situation maritale  \
# 4444  RIWC Jan - Mar, 2024         Blended  ...                NaN
#
#      Pays de naissance Pays d_où vous avez immigré_immigrerez  \
# 4444               NaN                                    NaN
#
#      Année d_arrivée au Canada _saisir 0 si non applicable_  \
# 4444                                                NaN
#
#      Plus haut niveau de formation  \
# 4444                           NaN
#
#      Quelle est votre situation professionnelle actuelle  \
# 4444                                                NaN
#
#      Dans quel secteur dactivite ou industrie travaillez_vous  \
# 4444                                                NaN
#
#      Est_ce votre secteur ou industrie de prédilection  \
# 4444                                               NaN
#
#       Quel est votre salaire annuel actuel            Quarterly
# 4444                                   NaN  Jan 2024 - Mar 2024
#
# [1 rows x 42 columns]

# %%
# Drop duplicate rows
df_survey = df_survey.drop_duplicates()

df_survey.reset_index(drop=True, inplace=True)

# %%
duplicates = df_survey[df_survey.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Username, CourseName, ChapterName, LessonName, Question, UserAnswer, CompletionDate, DepartmentName, Cohort Name, Program Version, ActiveStatus, Gender, Age, Status in Canada, Genre, Marital Status, Country of Birth, Country you have_will immigrate from, Year landed in Canada _enter 0 if not yet landed_, Highest level of education, Country, Province, City, What is your current employment status, What industry or sector are you working in, Is this your preferred industry or sector, What is your current annual employment salary, FirstName, LastName, Phone number,  Âge, Statut au Canada, Situation maritale, Pays de naissance, Pays d_où vous avez immigré_immigrerez, Année d_arrivée au Canada _saisir 0 si non applicable_, Plus haut niveau de formation, Quelle est votre situation professionnelle actuelle, Dans quel secteur dactivite ou industrie travaillez_vous, Est_ce votre secteur ou industrie de prédilection, Quel est votre salaire annuel actuel, Quarterly]
# Index: []
#
# [0 rows x 42 columns]

# %%
# Print rows with index labels from 4440 to 4450
print(df_survey.loc[4440:4450])
# Out:
#                    Username  \
# 4440  pdpatel2330@gmail.com
# 4441  pdpatel2330@gmail.com
# 4442  pdpatel2330@gmail.com
# 4443  pdpatel2330@gmail.com
# 4444  pdpatel2330@gmail.com
# 4445  pdpatel2330@gmail.com
# 4446  pdpatel2330@gmail.com
# 4447  pdpatel2330@gmail.com
# 4448  pdpatel2330@gmail.com
# 4449  pdpatel2330@gmail.com
# 4450  pdpatel2330@gmail.com
#
#                                              CourseName  \
# 4440  Module 6: Onboarding and organizational cultur...
# 4441  Module 6: Onboarding and organizational cultur...
# 4442  Module 6: Onboarding and organizational cultur...
# 4443  Module 6: Onboarding and organizational cultur...
# 4444  Module 6: Onboarding and organizational cultur...
# 4445         Module 7: Career progression (Blended v.5)
# 4446         Module 7: Career progression (Blended v.5)
# 4447         Module 7: Career progression (Blended v.5)
# 4448         Module 7: Career progression (Blended v.5)
# 4449         Module 7: Career progression (Blended v.5)
# 4450         Module 7: Career progression (Blended v.5)
#
#                 ChapterName  \
# 4440  Workshop 5 Evaluation
# 4441  Workshop 5 Evaluation
# 4442  Workshop 5 Evaluation
# 4443  Workshop 5 Evaluation
# 4444  Workshop 5 Evaluation
# 4445  Workshop 6 Evaluation
# 4446  Workshop 6 Evaluation
# 4447  Workshop 6 Evaluation
# 4448  Workshop 6 Evaluation
# 4449  Workshop 6 Evaluation
# 4450  Workshop 6 Evaluation
# 4449         Blended  ...                NaN               NaN
# 4450         Blended  ...                NaN               NaN
#
#      Pays d_où vous avez immigré_immigrerez  \
# 4440                                    NaN
# 4441                                    NaN
# 4442                                    NaN
# 4443                                    NaN
# 4444                                    NaN
# 4445                                    NaN
# 4446                                    NaN
# 4447                                    NaN
# 4448                                    NaN
# 4449                                    NaN
# 4450                                    NaN
#
#      Année d_arrivée au Canada _saisir 0 si non applicable_  \
# 4440                                                NaN
# 4441                                                NaN
# 4442                                                NaN
# 4443                                                NaN
# 4444                                                NaN
# 4445                                                NaN
# 4446                                                NaN
# 4447                                                NaN
# 4448                                                NaN
# 4449                                                NaN
# 4450                                                NaN
#
#      Plus haut niveau de formation  \
# 4440                           NaN
# 4441                           NaN
# 4442                           NaN
# 4443                           NaN
# 4444                           NaN
# 4445                           NaN
# 4446                           NaN
# 4447                           NaN
# 4448                           NaN
# 4449                           NaN
# 4450                           NaN
#
#      Quelle est votre situation professionnelle actuelle  \
# 4440                                                NaN
# 4441                                                NaN
# 4442                                                NaN
# 4443                                                NaN
# 4444                                                NaN
# 4445                                                NaN
# 4446                                                NaN
# 4447                                                NaN
# 4448                                                NaN
# 4449                                                NaN
# 4450                                                NaN
#
#      Dans quel secteur dactivite ou industrie travaillez_vous  \
# 4440                                                NaN
# 4441                                                NaN
# 4442                                                NaN
# 4443                                                NaN
# 4444                                                NaN
# 4445                                                NaN
# 4446                                                NaN
# 4447                                                NaN
# 4448                                                NaN
# 4449                                                NaN
# 4450                                                NaN
#
#      Est_ce votre secteur ou industrie de prédilection  \
# 4440                                               NaN
# 4441                                               NaN
# 4442                                               NaN
# 4443                                               NaN
# 4444                                               NaN
# 4445                                               NaN
# 4446                                               NaN
# 4447                                               NaN
# 4448                                               NaN
# 4449                                               NaN
# 4450                                               NaN
#
#       Quel est votre salaire annuel actuel            Quarterly
# 4440                                   NaN  Jan 2024 - Mar 2024
# 4441                                   NaN  Jan 2024 - Mar 2024
# 4442                                   NaN  Jan 2024 - Mar 2024
# 4443                                   NaN  Jan 2024 - Mar 2024
# 4444                                   NaN  Jan 2024 - Mar 2024
# 4445                                   NaN  Jan 2024 - Mar 2024
# 4446                                   NaN  Jan 2024 - Mar 2024
# 4447                                   NaN  Jan 2024 - Mar 2024
# 4448                                   NaN  Jan 2024 - Mar 2024
# 4449                                   NaN  Jan 2024 - Mar 2024
# 4450                                   NaN  Jan 2024 - Mar 2024
#
# [11 rows x 42 columns]

# %%
df_survey.drop(4446, inplace=True)  # Entry mistake

# %%
print(df_survey.isnull().sum())
# Out:
# Username                                                        0
# CourseName                                                      0
# ChapterName                                                     0
# LessonName                                                      0
# Question                                                        0
# UserAnswer                                                   2568
# CompletionDate                                                  0
# DepartmentName                                                  0
# Cohort Name                                                     5
# Program Version                                                 5
# ActiveStatus                                                    0
# Gender                                                       1015
# Age                                                          1015
# Status in Canada                                             1015
# Genre                                                       28373
# Marital Status                                               1015
# Country of Birth                                             1015
# Country you have_will immigrate from                         1159
# Year landed in Canada _enter 0 if not yet landed_            1015
# Highest level of education                                   1015
# Country                                                         0
# Province                                                        0
# City                                                            0
# What is your current employment status                       1531
# What industry or sector are you working in                   1531
# Is this your preferred industry or sector                    1531
# What is your current annual employment salary                1531
# FirstName                                                       0
# LastName                                                        0
# Phone number                                                    0
#  Âge                                                        28373
# Statut au Canada                                            28373
# Situation maritale                                          29191
# Pays de naissance                                           28391
# Pays d_où vous avez immigré_immigrerez                      28391
# Année d_arrivée au Canada _saisir 0 si non applicable_      28391
# Plus haut niveau de formation                               28373
# Quelle est votre situation professionnelle actuelle         28391
# Dans quel secteur dactivite ou industrie travaillez_vous    28391
# Est_ce votre secteur ou industrie de prédilection           28391
# Quel est votre salaire annuel actuel                        28391
# Quarterly                                                       0
# dtype: int64

# %% [markdown]
# Dropping Ascend Demo

# %%
filtered_df = df_survey[df_survey['Username'].isin(['ascend-demo@ascend.com', 'ascend_equipe_francais@ascend.com', 'ASCEND-EQUIPE@ascend.com'])]
print(filtered_df)
# Out:
#                                Username  \
# 509              ascend-demo@ascend.com
# 510              ascend-demo@ascend.com
# 511              ascend-demo@ascend.com
# 512              ascend-demo@ascend.com
# 513              ascend-demo@ascend.com
# 6974  ascend_equipe_francais@ascend.com
# 6975  ascend_equipe_francais@ascend.com
# 6976  ascend_equipe_francais@ascend.com
# 6977  ascend_equipe_francais@ascend.com
# 6978  ascend_equipe_francais@ascend.com
# 6979  ascend_equipe_francais@ascend.com
# 6980  ascend_equipe_francais@ascend.com
# 6981  ascend_equipe_francais@ascend.com
# 6982  ascend_equipe_francais@ascend.com
# 6983  ascend_equipe_francais@ascend.com
# 6984  ascend_equipe_francais@ascend.com
# 6985  ascend_equipe_francais@ascend.com
# 6986  ascend_equipe_francais@ascend.com
# 6987  ascend_equipe_francais@ascend.com
# 6988  ascend_equipe_francais@ascend.com
# 6989  ascend_equipe_francais@ascend.com
# 6990  ascend_equipe_francais@ascend.com
# 6991  ascend_equipe_francais@ascend.com
# 6992           ASCEND-EQUIPE@ascend.com
# 6993           ASCEND-EQUIPE@ascend.com
# 6994           ASCEND-EQUIPE@ascend.com
# 6995           ASCEND-EQUIPE@ascend.com
# 6996           ASCEND-EQUIPE@ascend.com
# 6997           ASCEND-EQUIPE@ascend.com
# 6998           ASCEND-EQUIPE@ascend.com
# 6999           ASCEND-EQUIPE@ascend.com
# 7000           ASCEND-EQUIPE@ascend.com
# 7001           ASCEND-EQUIPE@ascend.com
# 7002           ASCEND-EQUIPE@ascend.com
# 7003           ASCEND-EQUIPE@ascend.com
# 7004           ASCEND-EQUIPE@ascend.com
# 7005           ASCEND-EQUIPE@ascend.com
# 7006           ASCEND-EQUIPE@ascend.com
# 7007           ASCEND-EQUIPE@ascend.com
# 7008           ASCEND-EQUIPE@ascend.com
# 7009           ASCEND-EQUIPE@ascend.com
#
#                                              CourseName  \
# 509   Module 4: Building your job search and intervi...
# 510   Module 4: Building your job search and intervi...
# 511   Module 4: Building your job search and intervi...
# 512   Module 4: Building your job search and intervi...
# 7009                                                  5  2023-08-25 14:22
#
#        DepartmentName             Cohort Name Program Version  ...  \
# 509       ASCEND Demo                     NaN             NaN  ...
# 510       ASCEND Demo                     NaN             NaN  ...
# 511       ASCEND Demo                     NaN             NaN  ...
# 512       ASCEND Demo                     NaN             NaN  ...
# 513       ASCEND Demo                     NaN             NaN  ...
# 6974  ASCEND Français  ASCEND Français Master          French  ...
# 6975  ASCEND Français  ASCEND Français Master          French  ...
# 6976  ASCEND Français  ASCEND Français Master          French  ...
# 6977  ASCEND Français  ASCEND Français Master          French  ...
# 6978  ASCEND Français  ASCEND Français Master          French  ...
# 6979  ASCEND Français  ASCEND Français Master          French  ...
# 6980  ASCEND Français  ASCEND Français Master          French  ...
# 6981  ASCEND Français  ASCEND Français Master          French  ...
# 6982  ASCEND Français  ASCEND Français Master          French  ...
# 6983  ASCEND Français  ASCEND Français Master          French  ...
# 6984  ASCEND Français  ASCEND Français Master          French  ...
# 6985  ASCEND Français  ASCEND Français Master          French  ...
# 6986  ASCEND Français  ASCEND Français Master          French  ...
# 6987  ASCEND Français  ASCEND Français Master          French  ...
# 6988  ASCEND Français  ASCEND Français Master          French  ...
# 6989  ASCEND Français  ASCEND Français Master          French  ...
# 6990  ASCEND Français  ASCEND Français Master          French  ...
# 6991  ASCEND Français  ASCEND Français Master          French  ...
# 6992  ASCEND Français  ASCEND Français Master          French  ...
# 6993  ASCEND Français  ASCEND Français Master          French  ...
# 6994  ASCEND Français  ASCEND Français Master          French  ...
# 6995  ASCEND Français  ASCEND Français Master          French  ...
# 6996  ASCEND Français  ASCEND Français Master          French  ...
# 6997  ASCEND Français  ASCEND Français Master          French  ...
# 6998  ASCEND Français  ASCEND Français Master          French  ...
# 6999  ASCEND Français  ASCEND Français Master          French  ...
# 7000  ASCEND Français  ASCEND Français Master          French  ...
# 7001  ASCEND Français  ASCEND Français Master          French  ...
# 7002  ASCEND Français  ASCEND Français Master          French  ...
# 7003  ASCEND Français  ASCEND Français Master          French  ...
# 7004  ASCEND Français  ASCEND Français Master          French  ...
# 7005  ASCEND Français  ASCEND Français Master          French  ...
# 7006  ASCEND Français  ASCEND Français Master          French  ...
# 7007  ASCEND Français  ASCEND Français Master          French  ...
# 7008  ASCEND Français  ASCEND Français Master          French  ...
# 7009  ASCEND Français  ASCEND Français Master          French  ...
#
#             Situation maritale Pays de naissance  \
# 509                        NaN               NaN
# 510                        NaN               NaN
# 511                        NaN               NaN
# 512                        NaN               NaN
# 513                        NaN               NaN
# 6974  Marié.e / En concubinage            France
# 6975  Marié.e / En concubinage            France
# 6976  Marié.e / En concubinage            France
# 6977  Marié.e / En concubinage            France
# 6978  Marié.e / En concubinage            France
# 6979  Marié.e / En concubinage            France
# 6980  Marié.e / En concubinage            France
# 6981  Marié.e / En concubinage            France
# 6982  Marié.e / En concubinage            France
# 6983  Marié.e / En concubinage            France
# 6984  Marié.e / En concubinage            France
# 6985  Marié.e / En concubinage            France
# 6986  Marié.e / En concubinage            France
# 7009                                   NaN  July 2023 - Sep2023
#
# [41 rows x 42 columns]

# %%
usernames_to_drop = ['ascend-demo@ascend.com', 'ascend_equipe_francais@ascend.com', 'ASCEND-EQUIPE@ascend.com']

df_survey = df_survey[~df_survey['Username'].isin(usernames_to_drop)]
df_survey.reset_index(drop=True, inplace=True)

print(df_survey)
# Out:
#                     Username                          CourseName  \
# 0          10049na@gmail.com  00. Pre-program consent and survey
# 1          10049na@gmail.com  00. Pre-program consent and survey
# 2          10049na@gmail.com  00. Pre-program consent and survey
# 3          10049na@gmail.com  00. Pre-program consent and survey
# 4          10049na@gmail.com  00. Pre-program consent and survey
# ...                      ...                                 ...
# 29327  Zinnyminhas@yahoo.com      Your Certificate of Completion
# 29328  Zinnyminhas@yahoo.com      Your Certificate of Completion
# 29329  Zinnyminhas@yahoo.com      Your Certificate of Completion
# 29330  Zinnyminhas@yahoo.com      Your Certificate of Completion
# 29331  Zinnyminhas@yahoo.com      Your Certificate of Completion
#
#                       ChapterName  \
# 0       ASCEND pre-program survey
# 1       ASCEND pre-program survey
# 2       ASCEND pre-program survey
# 3       ASCEND pre-program survey
# 4       ASCEND pre-program survey
# ...                           ...
# 29327  ASCEND Post-Program Survey
# 29328  ASCEND Post-Program Survey
# 29329  ASCEND Post-Program Survey
# 29330  ASCEND Post-Program Survey
# 29331  ASCEND Post-Program Survey
#
#                                               LessonName  \
# 0        Pre-program survey: Soft skills self-assessment
# 1        Pre-program survey: Soft skills self-assessment
# 2        Pre-program survey: Soft skills self-assessment
# 3        Pre-program survey: Soft skills self-assessment
# 4        Pre-program survey: Soft skills self-assessment
# ...                                                  ...
# 29327  Post-program survey: Part 2 - Soft skills self...
# 29328  Post-program survey: Part 2 - Soft skills self...
# 29329  Post-program survey: Part 2 - Soft skills self...
# 29330  Post-program survey: Part 2 - Soft skills self...
# 29331  Post-program survey: Part 2 - Soft skills self...
#
#                                                 Question UserAnswer  \
# 0      I am able to identify new professional network...          4
# 1      I am able to negotiate a job salary\n(5 = Stro...          3
# 2      I am comfortable searching for potential jobs ...          4
# 3      I am confident in my ability to use effective ...          3
# 4      I am confident in my interview skills\n(5 = St...          3
# ...                                                  ...        ...
# 29327  I believe I HAVE the soft skills that Canadian...          4
# 29328  I believe I UNDERSTAND the soft skills that Ca...          5
# 29329  I feel well-prepared to work in Canada in a po...          5
# 29330  I know my professional development and career ...          5
# 29331  Would you be interested in sharing your experi...        Yes
#
#          CompletionDate                                     DepartmentName  \
# 0      2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 1      2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 2      2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 3      2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# 4      2024-02-05 17:45  Victoria Immigrant Refugee Centre Society (VIRCS)
# ...                 ...                                                ...
# 29327  2023-12-09 18:22  Progressive Intercultural Community Services (...
# 29328  2023-12-09 18:22  Progressive Intercultural Community Services (...
# 29329  2023-12-09 18:22  Progressive Intercultural Community Services (...
# 29330  2023-12-09 18:22  Progressive Intercultural Community Services (...
# 29331  2023-12-09 18:22  Progressive Intercultural Community Services (...
#
#                  Cohort Name Program Version  ... Situation maritale  \
# 0      VIRCS Feb - Apr, 2024          Online  ...                NaN
# 1      VIRCS Feb - Apr, 2024          Online  ...                NaN
# 2      VIRCS Feb - Apr, 2024          Online  ...                NaN
# 3      VIRCS Feb - Apr, 2024          Online  ...                NaN
# 4      VIRCS Feb - Apr, 2024          Online  ...                NaN
# ...                      ...             ...  ...                ...
# 29327    PICS Oct- Dec, 2023         Blended  ...                NaN
# 29328    PICS Oct- Dec, 2023         Blended  ...                NaN
# 29329    PICS Oct- Dec, 2023         Blended  ...                NaN
# 29330    PICS Oct- Dec, 2023         Blended  ...                NaN
# 29331    PICS Oct- Dec, 2023         Blended  ...                NaN
#
#       Pays de naissance Pays d_où vous avez immigré_immigrerez  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 29327               NaN                                    NaN
# 29328               NaN                                    NaN
# 29329               NaN                                    NaN
# 29330               NaN                                    NaN
# 29331               NaN                                    NaN
#
#       Année d_arrivée au Canada _saisir 0 si non applicable_  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29327                                                NaN
# 29328                                                NaN
# 29329                                                NaN
# 29330                                                NaN
# 29331                                                NaN
#
#       Plus haut niveau de formation  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 29327                           NaN
# 29328                           NaN
# 29329                           NaN
# 29330                           NaN
# 29331                           NaN
#
#       Quelle est votre situation professionnelle actuelle  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29327                                                NaN
# 29328                                                NaN
# 29329                                                NaN
# 29330                                                NaN
# 29331                                                NaN
#
#       Dans quel secteur dactivite ou industrie travaillez_vous  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29327                                                NaN
# 29328                                                NaN
# 29329                                                NaN
# 29330                                                NaN
# 29331                                                NaN
#
#       Est_ce votre secteur ou industrie de prédilection  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 29327                                               NaN
# 29328                                               NaN
# 29329                                               NaN
# 29330                                               NaN
# 29331                                               NaN
#
#        Quel est votre salaire annuel actuel            Quarterly
# 0                                       NaN  Jan 2024 - Mar 2024
# 1                                       NaN  Jan 2024 - Mar 2024
# 2                                       NaN  Jan 2024 - Mar 2024
# 3                                       NaN  Jan 2024 - Mar 2024
# 4                                       NaN  Jan 2024 - Mar 2024
# ...                                     ...                  ...
# 29327                                   NaN  Oct 2023 - Dec 2023
# 29328                                   NaN  Oct 2023 - Dec 2023
# 29329                                   NaN  Oct 2023 - Dec 2023
# 29330                                   NaN  Oct 2023 - Dec 2023
# 29331                                   NaN  Oct 2023 - Dec 2023
#
# [29332 rows x 42 columns]

# %%
df_survey.shape
# Out:
# (29332, 42)

# %%
print(df_survey.isnull().sum())
# Out:
# Username                                                        0
# CourseName                                                      0
# ChapterName                                                     0
# LessonName                                                      0
# Question                                                        0
# UserAnswer                                                   2565
# CompletionDate                                                  0
# DepartmentName                                                  0
# Cohort Name                                                     0
# Program Version                                                 0
# ActiveStatus                                                    0
# Gender                                                        974
# Age                                                           974
# Status in Canada                                              974
# Genre                                                       28368
# Marital Status                                                974
# Country of Birth                                              974
# Country you have_will immigrate from                         1118
# Year landed in Canada _enter 0 if not yet landed_             974
# Highest level of education                                    974
# Country                                                         0
# Province                                                        0
# City                                                            0
# What is your current employment status                       1490
# What industry or sector are you working in                   1490
# Is this your preferred industry or sector                    1490
# What is your current annual employment salary                1490
# FirstName                                                       0
# LastName                                                        0
# Phone number                                                    0
#  Âge                                                        28368
# Statut au Canada                                            28368
# Situation maritale                                          29186
# Pays de naissance                                           28368
# Pays d_où vous avez immigré_immigrerez                      28368
# Année d_arrivée au Canada _saisir 0 si non applicable_      28368
# Plus haut niveau de formation                               28368
# Quelle est votre situation professionnelle actuelle         28368
# Dans quel secteur dactivite ou industrie travaillez_vous    28368
# Est_ce votre secteur ou industrie de prédilection           28368
# Quel est votre salaire annuel actuel                        28368
# Quarterly                                                       0
# dtype: int64

# %% [markdown]
# **Separating French and English Category**

# %%
df_survey['Language Category'] = 'English'
df_survey.loc[df_survey['Program Version'].isin(['French', 'French Facilitator','SDECB']), 'Language Category'] = 'French'

print(df_survey['Language Category'].value_counts())
# Out:
# Language Category
# English    28358
# French       974
# Name: count, dtype: int64

# %%
df_French = df_survey[df_survey['Language Category'] == 'French']
df_English = df_survey[df_survey['Language Category'] == 'English']

# %% [markdown]
# **Data Cleaning of French Category**

# %%
print(df_French.isnull().sum())
# Out:
# Username                                                      0
# CourseName                                                    0
# ChapterName                                                   0
# LessonName                                                    0
# Question                                                      0
# UserAnswer                                                    5
# CompletionDate                                                0
# DepartmentName                                                0
# Cohort Name                                                   0
# Program Version                                               0
# ActiveStatus                                                  0
# Gender                                                      974
# Age                                                         974
# Status in Canada                                            974
# Genre                                                        10
# Marital Status                                              974
# Country of Birth                                            974
# Country you have_will immigrate from                        974
# Year landed in Canada _enter 0 if not yet landed_           974
# Highest level of education                                  974
# Country                                                       0
# Province                                                      0
# City                                                          0
# What is your current employment status                      974
# What industry or sector are you working in                  974
# Is this your preferred industry or sector                   974
# What is your current annual employment salary               974
# FirstName                                                     0
# LastName                                                      0
# Phone number                                                  0
#  Âge                                                         10
# Statut au Canada                                             10
# Situation maritale                                          828
# Pays de naissance                                            10
# Pays d_où vous avez immigré_immigrerez                       10
# Année d_arrivée au Canada _saisir 0 si non applicable_       10
# Plus haut niveau de formation                                10
# Quelle est votre situation professionnelle actuelle          10
# Dans quel secteur dactivite ou industrie travaillez_vous     10
# Est_ce votre secteur ou industrie de prédilection            10
# Quel est votre salaire annuel actuel                         10
# Quarterly                                                     0
# Language Category                                             0
# dtype: int64

# %%
columns_to_drop = [
    'Gender',
    'Age',
    'Status in Canada',
    'Marital Status',
    'Country of Birth',
    'Country you have_will immigrate from',
    'Year landed in Canada _enter 0 if not yet landed_',
    'Highest level of education',
    'What is your current employment status',
    'What industry or sector are you working in',
    'Is this your preferred industry or sector',
    'What is your current annual employment salary'
]

df_French.drop(columns=columns_to_drop,inplace=True)
# Out:
# <ipython-input-20-e4ba128373d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French.drop(columns=columns_to_drop,inplace=True)

# %%
print(df_French.isnull().sum())
# Out:
# Username                                                      0
# CourseName                                                    0
# ChapterName                                                   0
# LessonName                                                    0
# Question                                                      0
# UserAnswer                                                    5
# CompletionDate                                                0
# DepartmentName                                                0
# Cohort Name                                                   0
# Program Version                                               0
# ActiveStatus                                                  0
# Genre                                                        10
# Country                                                       0
# Province                                                      0
# City                                                          0
# FirstName                                                     0
# LastName                                                      0
# Phone number                                                  0
#  Âge                                                         10
# Statut au Canada                                             10
# Situation maritale                                          828
# Pays de naissance                                            10
# Pays d_où vous avez immigré_immigrerez                       10
# Année d_arrivée au Canada _saisir 0 si non applicable_       10
# Plus haut niveau de formation                                10
# Quelle est votre situation professionnelle actuelle          10
# Dans quel secteur dactivite ou industrie travaillez_vous     10
# Est_ce votre secteur ou industrie de prédilection            10
# Quel est votre salaire annuel actuel                         10
# Quarterly                                                     0
# Language Category                                             0
# dtype: int64

# %% [markdown]
# Handling missing values of French Category

# %%
df_French['UserAnswer'].fillna('NA', inplace=True)
df_French['Situation maritale'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
df_French['Statut au Canada'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
df_French['Genre'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)

df_French[' Âge'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
df_French['Pays de naissance'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)    #country of birth
df_French['Pays d_où vous avez immigré_immigrerez'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)   # immigration country


df_French['Plus haut niveau de formation'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)   # Highest education
df_French['Quelle est votre situation professionnelle actuelle'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True) #current employment
df_French['Dans quel secteur dactivite ou industrie travaillez_vous'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #industry

df_French['Est_ce votre secteur ou industrie de prédilection'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #is this ur prefered sector
df_French['Quel est votre salaire annuel actuel'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #annual sal
# Out:
# <ipython-input-22-4f2a5be30e8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['UserAnswer'].fillna('NA', inplace=True)
# <ipython-input-22-4f2a5be30e8b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Situation maritale'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
# <ipython-input-22-4f2a5be30e8b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Statut au Canada'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
# <ipython-input-22-4f2a5be30e8b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Genre'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
# <ipython-input-22-4f2a5be30e8b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French[' Âge'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)
# <ipython-input-22-4f2a5be30e8b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Pays de naissance'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)    #country of birth
# <ipython-input-22-4f2a5be30e8b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Pays d_où vous avez immigré_immigrerez'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)   # immigration country
# <ipython-input-22-4f2a5be30e8b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Plus haut niveau de formation'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)   # Highest education
# <ipython-input-22-4f2a5be30e8b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Quelle est votre situation professionnelle actuelle'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True) #current employment
# <ipython-input-22-4f2a5be30e8b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Dans quel secteur dactivite ou industrie travaillez_vous'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #industry
# <ipython-input-22-4f2a5be30e8b>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Est_ce votre secteur ou industrie de prédilection'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #is this ur prefered sector
# <ipython-input-22-4f2a5be30e8b>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Quel est votre salaire annuel actuel'].fillna('PrÃ©fÃ¨re ne pas rÃ©pondre', inplace=True)  #annual sal

# %%
print(df_French.isnull().sum())
# Out:
# Username                                                     0
# CourseName                                                   0
# ChapterName                                                  0
# LessonName                                                   0
# Question                                                     0
# UserAnswer                                                   0
# CompletionDate                                               0
# DepartmentName                                               0
# Cohort Name                                                  0
# Program Version                                              0
# ActiveStatus                                                 0
# Genre                                                        0
# Country                                                      0
# Province                                                     0
# City                                                         0
# FirstName                                                    0
# LastName                                                     0
# Phone number                                                 0
#  Âge                                                         0
# Statut au Canada                                             0
# Situation maritale                                           0
# Pays de naissance                                            0
# Pays d_où vous avez immigré_immigrerez                       0
# Année d_arrivée au Canada _saisir 0 si non applicable_      10
# Plus haut niveau de formation                                0
# Quelle est votre situation professionnelle actuelle          0
# Dans quel secteur dactivite ou industrie travaillez_vous     0
# Est_ce votre secteur ou industrie de prédilection            0
# Quel est votre salaire annuel actuel                         0
# Quarterly                                                    0
# Language Category                                            0
# dtype: int64

# %%
most_frequent_value = df_French['Année d_arrivée au Canada _saisir 0 si non applicable_'].mode()[0]

df_French['Année d_arrivée au Canada _saisir 0 si non applicable_'].fillna(most_frequent_value, inplace=True)
# Out:
# <ipython-input-31-ef4324c78f9f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_French['Année d_arrivée au Canada _saisir 0 si non applicable_'].fillna(most_frequent_value, inplace=True)

# %%
print(df_French.isnull().sum())
# Out:
# Username                                                    0
# CourseName                                                  0
# ChapterName                                                 0
# LessonName                                                  0
# Question                                                    0
# UserAnswer                                                  0
# CompletionDate                                              0
# DepartmentName                                              0
# Cohort Name                                                 0
# Program Version                                             0
# ActiveStatus                                                0
# Genre                                                       0
# Country                                                     0
# Province                                                    0
# City                                                        0
# FirstName                                                   0
# LastName                                                    0
# Phone number                                                0
#  Âge                                                        0
# Statut au Canada                                            0
# Situation maritale                                          0
# Pays de naissance                                           0
# Pays d_où vous avez immigré_immigrerez                      0
# Année d_arrivée au Canada _saisir 0 si non applicable_      0
# Plus haut niveau de formation                               0
# Quelle est votre situation professionnelle actuelle         0
# Dans quel secteur dactivite ou industrie travaillez_vous    0
# Est_ce votre secteur ou industrie de prédilection           0
# Quel est votre salaire annuel actuel                        0
# Quarterly                                                   0
# Language Category                                           0
# dtype: int64

# %% [markdown]
# **Data Cleaning of English Category**

# %%
print(df_English.isnull().sum())
# Out:
# Username                                                        0
# CourseName                                                      0
# ChapterName                                                     0
# LessonName                                                      0
# Question                                                        0
# UserAnswer                                                   2560
# CompletionDate                                                  0
# DepartmentName                                                  0
# Cohort Name                                                     0
# Program Version                                                 0
# ActiveStatus                                                    0
# Gender                                                          0
# Age                                                             0
# Status in Canada                                                0
# Genre                                                       28358
# Marital Status                                                  0
# Country of Birth                                                0
# Country you have_will immigrate from                          144
# Year landed in Canada _enter 0 if not yet landed_               0
# Highest level of education                                      0
# Country                                                         0
# Province                                                        0
# City                                                            0
# What is your current employment status                        516
# What industry or sector are you working in                    516
# Is this your preferred industry or sector                     516
# What is your current annual employment salary                 516
# FirstName                                                       0
# LastName                                                        0
# Phone number                                                    0
#  Âge                                                        28358
# Statut au Canada                                            28358
# Situation maritale                                          28358
# Pays de naissance                                           28358
# Pays d_où vous avez immigré_immigrerez                      28358
# Année d_arrivée au Canada _saisir 0 si non applicable_      28358
# Plus haut niveau de formation                               28358
# Quelle est votre situation professionnelle actuelle         28358
# Dans quel secteur dactivite ou industrie travaillez_vous    28358
# Est_ce votre secteur ou industrie de prédilection           28358
# Quel est votre salaire annuel actuel                        28358
# Quarterly                                                       0
# Language Category                                               0
# dtype: int64

# %%
columns_to_drop = [
    'Genre',
    ' Âge',
    'Statut au Canada',
    'Situation maritale',
    'Pays de naissance',
    'Pays d_où vous avez immigré_immigrerez',
    'Année d_arrivée au Canada _saisir 0 si non applicable_',
    'Plus haut niveau de formation',
    'Quelle est votre situation professionnelle actuelle',
    'Dans quel secteur dactivite ou industrie travaillez_vous',
    'Est_ce votre secteur ou industrie de prédilection',
    'Quel est votre salaire annuel actuel'
]

df_English.drop(columns=columns_to_drop, inplace=True)
# Out:
# <ipython-input-25-12b31ee27210>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English.drop(columns=columns_to_drop, inplace=True)

# %%
print(df_English.isnull().sum())
# Out:
# Username                                                0
# CourseName                                              0
# ChapterName                                             0
# LessonName                                              0
# Question                                                0
# UserAnswer                                           2560
# CompletionDate                                          0
# DepartmentName                                          0
# Cohort Name                                             0
# Program Version                                         0
# ActiveStatus                                            0
# Gender                                                  0
# Age                                                     0
# Status in Canada                                        0
# Marital Status                                          0
# Country of Birth                                        0
# Country you have_will immigrate from                  144
# Year landed in Canada _enter 0 if not yet landed_       0
# Highest level of education                              0
# Country                                                 0
# Province                                                0
# City                                                    0
# What is your current employment status                516
# What industry or sector are you working in            516
# Is this your preferred industry or sector             516
# What is your current annual employment salary         516
# FirstName                                               0
# LastName                                                0
# Phone number                                            0
# Quarterly                                               0
# Language Category                                       0
# dtype: int64

# %%
df_English['UserAnswer'].fillna('NA', inplace=True)

df_English['Age'].fillna('Prefer not to disclose', inplace=True)

df_English['Gender'].fillna('Prefer not to disclose', inplace=True)

df_English['Marital Status'].fillna('Prefer not to disclose', inplace=True)

df_English['Country of Birth'].fillna('Prefer not to disclose', inplace=True)

df_English['Country you have_will immigrate from'].fillna('Prefer not to disclose', inplace=True)

df_English['Highest level of education'].fillna('Prefer not to disclose', inplace=True)

df_English['What is your current employment status'].fillna('Prefer not to disclose', inplace=True)

df_English['What industry or sector are you working in'].fillna('Prefer not to disclose', inplace=True)

df_English['What is your current annual employment salary'].fillna('Prefer not to disclose', inplace=True)

df_English['Is this your preferred industry or sector'].fillna('Prefer not to disclose', inplace=True)
# Out:
# <ipython-input-27-323bfafe1ba1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['UserAnswer'].fillna('NA', inplace=True)
# <ipython-input-27-323bfafe1ba1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Age'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Gender'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Marital Status'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Country of Birth'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Country you have_will immigrate from'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Highest level of education'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['What is your current employment status'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['What industry or sector are you working in'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['What is your current annual employment salary'].fillna('Prefer not to disclose', inplace=True)
# <ipython-input-27-323bfafe1ba1>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_English['Is this your preferred industry or sector'].fillna('Prefer not to disclose', inplace=True)

# %%
df_English.loc[df_English['Username'] == 'feng.xiaom@northeastern.edu', 'Country of Birth'] = 'China'

df_English.loc[df_English['Username'] == 'fessehad27@gmail.com', 'Country of Birth'] = 'Ethiopia'

# %%
print(df_English.isnull().sum())
# Out:
# Username                                             0
# CourseName                                           0
# ChapterName                                          0
# LessonName                                           0
# Question                                             0
# UserAnswer                                           0
# CompletionDate                                       0
# DepartmentName                                       0
# Cohort Name                                          0
# Program Version                                      0
# ActiveStatus                                         0
# Gender                                               0
# Age                                                  0
# Status in Canada                                     0
# Marital Status                                       0
# Country of Birth                                     0
# Country you have_will immigrate from                 0
# Year landed in Canada _enter 0 if not yet landed_    0
# Highest level of education                           0
# Country                                              0
# Province                                             0
# City                                                 0
# What is your current employment status               0
# What industry or sector are you working in           0
# Is this your preferred industry or sector            0
# What is your current annual employment salary        0
# FirstName                                            0
# LastName                                             0
# Phone number                                         0
# Quarterly                                            0
# Language Category                                    0
# dtype: int64
